# %% [markdown]
# pyecharts文档：https://pyecharts.org/#/

# %%
 # 只需要在顶部声明 CurrentConfig.ONLINE_HOST 即可
 from pyecharts.globals import CurrentConfig, OnlineHostType

 # OnlineHostType.NOTEBOOK_HOST 默认值为 http://localhost:8888/nbextensions/assets/
 CurrentConfig.ONLINE_HOST = OnlineHostType.NOTEBOOK_HOST

# %% [markdown]
# 如果以下图无法渲染，可参考：
#
# https://zhuanlan.zhihu.com/p/408166097?utm_id=0
#
# https://blog.csdn.net/qq_44157558/article/details/126299709

# %% [markdown]
# # 热力图

# %%
import random

from pyecharts import options as opts
from pyecharts.charts import HeatMap
from pyecharts.faker import Faker

value = [[i, j, random.randint(0, 50)] for i in range(24) for j in range(7)]
c = (
    HeatMap()
    .add_xaxis(Faker.clock)
    .add_yaxis(
        "series0",
        Faker.week,
        value,
        label_opts=opts.LabelOpts(is_show=True, position="inside"),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="HeatMap-Label 显示"),
        visualmap_opts=opts.VisualMapOpts(),
    )
)
#c.load_javascript()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'http://localhost:8888/nbextensions/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3d6261feeb3b43f7a29c92b016d14ccb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3d6261feeb3b43f7a29c92b016d14ccb = echarts.init(
#                     document.getElementById('3d6261feeb3b43f7a29c92b016d14ccb'), 'white', {renderer: 'canvas'});
#                 var option_3d6261feeb3b43f7a29c92b016d14ccb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "series0",
#             "data": [
#                 [
#                     0,
#                     0,
#                     12
#                 ],
#                 [
#                     0,
#                     1,
#                     41
#                 ],
#                 [
#                     0,
#                     2,
#                     42
#                 ],
#                 [
#                     0,
#                     3,
#                     1
#                 ],
#                 [
#                     0,
#                     4,
#                     41
#                 ],
#                 [
#                     0,
#                     5,
#                     32
#                 ],
#                 [
#                     0,
#                     6,
#                     24
#                 ],
#                 [
#                     1,
#                     0,
#                     13
#                 ],
#                 [
#                     1,
#                     1,
#                     0
#                 ],
#                 [
#                     1,
#                     2,
#                     9
#                 ],
#                 [
#                     1,
#                     3,
#                     18
#                 ],
#                 [
#                     1,
#                     4,
#                     34
#                 ],
#                 [
#                     1,
#                     5,
#                     6
#                 ],
#                 [
#                     1,
#                     6,
#                     20
#                 ],
#                 [
#                     2,
#                     0,
#                     36
#                 ],
#                 [
#                     2,
#                     1,
#                     37
#                 ],
#                 [
#                     2,
#                     2,
#                     6
#                 ],
#                 [
#                     2,
#                     3,
#                     1
#                 ],
#                 [
#                     2,
#                     4,
#                     20
#                 ],
#                 [
#                     2,
#                     5,
#                     42
#                 ],
#                 [
#                     2,
#                     6,
#                     44
#                 ],
#                 [
#                     3,
#                     0,
#                     14
#                 ],
#                 [
#                     3,
#                     1,
#                     13
#                 ],
#                 [
#                     3,
#                     2,
#                     33
#                 ],
#                 [
#                     3,
#                     3,
#                     42
#                 ],
#                 [
#                     3,
#                     4,
#                     7
#                 ],
#                 [
#                     3,
#                     5,
#                     36
#                 ],
#                 [
#                     3,
#                     6,
#                     11
#                 ],
#                 [
#                     4,
#                     0,
#                     14
#                 ],
#                 [
#                     4,
#                     1,
#                     22
#                 ],
#                 [
#                     4,
#                     2,
#                     30
#                 ],
#                 [
#                     4,
#                     3,
#                     1
#                 ],
#                 [
#                     4,
#                     4,
#                     14
#                 ],
#                 [
#                     4,
#                     5,
#                     1
#                 ],
#                 [
#                     4,
#                     6,
#                     28
#                 ],
#                 [
#                     5,
#                     0,
#                     36
#                 ],
#                 [
#                     5,
#                     1,
#                     26
#                 ],
#                 [
#                     5,
#                     2,
#                     13
#                 ],
#                 [
#                     5,
#                     3,
#                     35
#                 ],
#                 [
#                     5,
#                     4,
#                     40
#                 ],
#                 [
#                     5,
#                     5,
#                     47
#                 ],
#                 [
#                     5,
#                     6,
#                     37
#                 ],
#                 [
#                     6,
#                     0,
#                     39
#                 ],
#                 [
#                     6,
#                     1,
#                     32
#                 ],
#                 [
#                     6,
#                     2,
#                     7
#                 ],
#                 [
#                     6,
#                     3,
#                     36
#                 ],
#                 [
#                     6,
#                     4,
#                     32
#                 ],
#                 [
#                     6,
#                     5,
#                     49
#                 ],
#                 [
#                     6,
#                     6,
#                     45
#                 ],
#                 [
#                     7,
#                     0,
#                     22
#                 ],
#                 [
#                     7,
#                     1,
#                     2
#                 ],
#                 [
#                     7,
#                     2,
#                     5
#                 ],
#                 [
#                     7,
#                     3,
#                     42
#                 ],
#                 [
#                     7,
#                     4,
#                     15
#                 ],
#                 [
#                     7,
#                     5,
#                     46
#                 ],
#                 [
#                     7,
#                     6,
#                     7
#                 ],
#                 [
#                     8,
#                     0,
#                     50
#                 ],
#                 [
#                     8,
#                     1,
#                     34
#                 ],
#                 [
#                     8,
#                     2,
#                     25
#                 ],
#                 [
#                     8,
#                     3,
#                     27
#                 ],
#                 [
#                     8,
#                     4,
#                     0
#                 ],
#                 [
#                     8,
#                     5,
#                     7
#                 ],
#                 [
#                     8,

# %% [markdown]
# class HeatMapItem(
#
#     # 数据项名称。
#
#     name: Optional[str] = None,
#
#     # 数据项的值。
#
#     value: Optional[Sequence] = None,
#
#     # 图元样式配置项，参考 `series_options.ItemStyleOpts`
#
#     itemstyle_opts: Union[ItemStyleOpts, dict, None] = None,
#
#     # 提示框组件配置项，参考 `series_options.TooltipOpts`
#
#     tooltip_opts: Union[TooltipOpts, dict, None] = None,
#
# )

# %% [markdown]
# # 仪表盘

# %%
from pyecharts import options as opts
from pyecharts.charts import Gauge

c = (
    Gauge()
    .add(
        "业务指标",
        [("\n\n完成率", 90)],
        axisline_opts=opts.AxisLineOpts(
            linestyle_opts=opts.LineStyleOpts(
                color=[(0.3, "#67e0e3"), (0.7, "#37a2da"), (1, "#fd666d")], width=30
            )
        ),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Gauge-不同颜色"),
        legend_opts=opts.LegendOpts(is_show=False),
    )
)
#c.load_javascript()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'http://localhost:8888/nbextensions/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d4f9194968594c68b831bfa725c71b49" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d4f9194968594c68b831bfa725c71b49 = echarts.init(
#                     document.getElementById('d4f9194968594c68b831bfa725c71b49'), 'white', {renderer: 'canvas'});
#                 var option_d4f9194968594c68b831bfa725c71b49 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "offsetCenter": [
#                     0,
#                     "-40%"
#                 ],
#                 "color": "#333",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 15,
#                 "backgroundColor": "transparent",
#                 "borderColor": "transparent",
#                 "borderWidth": 0,
#                 "borderRadius": 0,
#                 "padding": 0,
#                 "shadowColor": "transparent",
#                 "shadowBlur": 0,
#                 "shadowOffsetX": 0,
#                 "shadowOffsetY": 0
#             },
#             "detail": {
#                 "show": true,
#                 "backgroundColor": "transparent",
#                 "borderWidth": 0,
#                 "borderColor": "transparent",
#                 "offsetCenter": [
#                     0,
#                     "-40%"
#                 ],
#                 "formatter": "{value}%",
#                 "color": "auto",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 15,
#                 "borderRadius": 0,
#                 "padding": 0,
#                 "shadowColor": "transparent",
#                 "shadowBlur": 0,
#                 "shadowOffsetX": 0,
#                 "shadowOffsetY": 0
#             },
#             "name": "\u4e1a\u52a1\u6307\u6807",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "radius": "75%",
#             "startAngle": 225,
#             "endAngle": -45,
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\n\n\u5b8c\u6210\u7387",
#                     "value": 90
#                 }
#             ],
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 30,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": [
#                         [
#                             0.3,
#                             "#67e0e3"
#                         ],
#                         [
#                             0.7,
#                             "#37a2da"
#                         ],
#                         [
#                             1,
#                             "#fd666d"
#                         ]
#                     ]
#                 }
#             },
#             "pointer": {
#                 "show": true,
#                 "length": "80%",
#                 "width": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e1a\u52a1\u6307\u6807"
#             ],
#             "selected": {
#                 "\u4e1a\u52a1\u6307\u6807": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Gauge-\u4e0d\u540c\u989c\u8272",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_d4f9194968594c68b831bfa725c71b49.setOption(option_d4f9194968594c68b831bfa725c71b49);
#         });
#     </script>

# %% [markdown]
# # 饼图

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie

c = (
    Pie()
    .add_dataset(
        source=[
            ["product", "2012", "2013", "2014", "2015", "2016", "2017"],
            ["Matcha Latte", 41.1, 30.4, 65.1, 53.3, 83.8, 98.7],
            ["Milk Tea", 86.5, 92.1, 85.7, 83.1, 73.4, 55.1],
            ["Cheese Cocoa", 24.1, 67.2, 79.5, 86.4, 65.2, 82.5],
            ["Walnut Brownie", 55.2, 67.1, 69.2, 72.4, 53.9, 39.1],
        ]
    )
    .add(
        series_name="Matcha Latte",
        data_pair=[],
        radius=60,
        center=["25%", "30%"],
        encode={"itemName": "product", "value": "2012"},
    )
    .add(
        series_name="Milk Tea",
        data_pair=[],
        radius=60,
        center=["75%", "30%"],
        encode={"itemName": "product", "value": "2013"},
    )
    .add(
        series_name="Cheese Cocoa",
        data_pair=[],
        radius=60,
        center=["25%", "75%"],
        encode={"itemName": "product", "value": "2014"},
    )
    .add(
        series_name="Walnut Brownie",
        data_pair=[],
        radius=60,
        center=["75%", "75%"],
        encode={"itemName": "product", "value": "2015"},
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Dataset simple pie example"),
        legend_opts=opts.LegendOpts(pos_left="30%", pos_top="2%"),
    )
)
#c.load_javascript()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'http://localhost:8888/nbextensions/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a76691875bcd4069b0d85169d3d7ed9b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a76691875bcd4069b0d85169d3d7ed9b = echarts.init(
#                     document.getElementById('a76691875bcd4069b0d85169d3d7ed9b'), 'white', {renderer: 'canvas'});
#                 var option_a76691875bcd4069b0d85169d3d7ed9b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "Matcha Latte",
#             "clockwise": true,
#             "radius": 60,
#             "center": [
#                 "25%",
#                 "30%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "encode": {
#                 "itemName": "product",
#                 "value": "2012"
#             }
#         },
#         {
#             "type": "pie",
#             "name": "Milk Tea",
#             "clockwise": true,
#             "radius": 60,
#             "center": [
#                 "75%",
#                 "30%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "encode": {
#                 "itemName": "product",
#                 "value": "2013"
#             }
#         },
#         {
#             "type": "pie",
#             "name": "Cheese Cocoa",
#             "clockwise": true,
#             "radius": 60,
#             "center": [
#                 "25%",
#                 "75%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "encode": {
#                 "itemName": "product",
#                 "value": "2014"
#             }
#         },
#         {
#             "type": "pie",
#             "name": "Walnut Brownie",
#             "clockwise": true,
#             "radius": 60,
#             "center": [
#                 "75%",
#                 "75%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "encode": {
#                 "itemName": "product",
#                 "value": "2015"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Matcha Latte",
#                 "Milk Tea",
#                 "Cheese Cocoa",
#                 "Walnut Brownie"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "30%",
#             "top": "2%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "dataset": {
#         "source": [
#             [
#                 "product",
#                 "2012",
#                 "2013",
#                 "2014",
#                 "2015",
#                 "2016",
#                 "2017"
#             ],
#             [
#                 "Matcha Latte",
#                 41.1,
#                 30.4,
#                 65.1,
#                 53.3,
#                 83.8,
#                 98.7
#             ],
#             [
#                 "Milk Tea",
#                 86.5,
#                 92.1,
#                 85.7,
#                 83.1,
#                 73.4,
#                 55.1
#             ],
#             [
#                 "Cheese Cocoa",
#                 24.1,
#                 67.2,
#                 79.5,
#                 86.4,
#                 65.2,
#                 82.5
#             ],
#             [
#                 "Walnut Brownie",
#                 55.2,
#                 67.1,
#                 69.2,
#                 72.4,
#                 53.9,
#                 39.1
#             ]
#         ]
#     },
#     "title": [
#         {
#             "text": "Dataset simple pie example",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_a76691875bcd4069b0d85169d3d7ed9b.setOption(option_a76691875bcd4069b0d85169d3d7ed9b);
#         });
#     </script>
